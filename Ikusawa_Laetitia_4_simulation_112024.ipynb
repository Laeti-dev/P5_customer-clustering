# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Methodology

# %% [markdown]
# Now that we chose a clustering model, it is important to understand when personas are changing too. In this perpective, we have to update the clustering model on a period frequencies in order to evaluate is customers behaviour is changing and how to adress them if it is so.
#
# In order to find the best period lapse to reevaluate our customer, we will use the past 2 years data and evaluate what are the frequencies of consumption behaviour chnages.

# %% [markdown]
# # Setting first tests data

# %%
df_orders = pd.read_pickle('../data/df_orders_details.pkl')
print(df_orders.info())
print(f"Last date of the dataset: {(df_orders['order_purchase_date'].max())}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116211 entries, 0 to 117917
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_unique_id             116211 non-null  object
#  1   order_id                       116211 non-null  object
#  2   order_status                   116211 non-null  object
#  3   item_price                     116211 non-null  float64
#  4   freight_value                  116211 non-null  float64
#  5   payment_value                  116211 non-null  float64
#  6   payment_sequential             116211 non-null  int64
#  7   payment_type                   116211 non-null  object
#  8   payment_installments           116211 non-null  int64
#  9   review_score                   116211 non-null  int64
#  10  product_category_name_english  116211 non-null  object
#  11  order_processing_time          116211 non-null  float64
#  12  order_purchase_date            116211 non-null  object
#  13  delivery_delay                 115672 non-null  float64
#  14  days_late_count                116211 non-null  float64
#  15  order_purchase_time_bin        116211 non-null  category
#  16  canceled_orders                116211 non-null  int64
# dtypes: category(1), float64(6), int64(4), object(6)
# memory usage: 15.2+ MB
# None
# Last date of the dataset: 2018-09-03

# %% [markdown]
# ## Evaluate the starting moment (We moved this step into the preparation of data step.)

# %%
# Instanciate the first dataset
first_order_date = pd.to_datetime(df_orders["order_purchase_date"].min())
# last_date_of_orders = pd.to_datetime("2017-12-31")

# Set the variables
f = [3,1]  # frequency of the period : base period and current period
period = ["month", "week"]  # period to calculate the frequency (week or month)
k = 4 # number of clusters

plot_ari_evolution(first_order_date, f, k, period)
# Out:
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# <class 'pandas.core.frame.DataFrame'>
# Index: 5273 entries, 0 to 5312
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_orders           5273 non-null   int64
#  1   total_expenses         5273 non-null   float64
#  2   average_review_score   5273 non-null   float64
#  3   days_since_last_order  5273 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 206.0 KB
# None
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# Appending ARI score 1.0 for period ending 2017-04-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-12 00:00:00 for 7229 orders.
# Appending ARI score 0.3082782940243271 for period ending 2017-04-12 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-19 00:00:00 for 7742 orders.
# Appending ARI score 0.3095071592933278 for period ending 2017-04-19 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-26 00:00:00 for 8576 orders.
# Appending ARI score 0.7018146208843182 for period ending 2017-04-26 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-03 00:00:00 for 9339 orders.
# Appending ARI score 0.36608544931465425 for period ending 2017-05-03 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-10 00:00:00 for 10286 orders.
# Appending ARI score 0.38329297580704336 for period ending 2017-05-10 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-17 00:00:00 for 11337 orders.
# Appending ARI score 0.375666683501343 for period ending 2017-05-17 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-24 00:00:00 for 12393 orders.
# Appending ARI score 0.7439427105842652 for period ending 2017-05-24 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-31 00:00:00 for 13286 orders.
# Appending ARI score 0.6692516260520821 for period ending 2017-05-31 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-07 00:00:00 for 14279 orders.
# Appending ARI score 0.6163000572722983 for period ending 2017-06-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-14 00:00:00 for 15252 orders.
# Appending ARI score 0.5520632648942515 for period ending 2017-06-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-21 00:00:00 for 16028 orders.
# Appending ARI score 0.5187738728983307 for period ending 2017-06-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-28 00:00:00 for 16814 orders.
# Appending ARI score 0.40487629059529406 for period ending 2017-06-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-05 00:00:00 for 17724 orders.
# Appending ARI score 0.3942967180471149 for period ending 2017-07-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-12 00:00:00 for 18778 orders.
# Appending ARI score 0.47727698739831775 for period ending 2017-07-12 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-19 00:00:00 for 20004 orders.
# Appending ARI score 0.40891695630638586 for period ending 2017-07-19 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-26 00:00:00 for 21080 orders.
# Appending ARI score 0.3999706682006721 for period ending 2017-07-26 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-02 00:00:00 for 22222 orders.
# Appending ARI score 0.5469018053934325 for period ending 2017-08-02 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-09 00:00:00 for 23396 orders.
# Appending ARI score 0.5122084075141253 for period ending 2017-08-09 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-16 00:00:00 for 24600 orders.
# Appending ARI score 0.3745783824541736 for period ending 2017-08-16 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-23 00:00:00 for 25735 orders.
# Appending ARI score 0.36461420688954704 for period ending 2017-08-23 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-30 00:00:00 for 26822 orders.
# Appending ARI score 0.4608381967331738 for period ending 2017-08-30 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-06 00:00:00 for 27995 orders.
# Appending ARI score 0.44743020070008893 for period ending 2017-09-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-13 00:00:00 for 29210 orders.
# Appending ARI score 0.36071978338554644 for period ending 2017-09-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-20 00:00:00 for 30467 orders.
# Appending ARI score 0.44053081646677505 for period ending 2017-09-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-27 00:00:00 for 31618 orders.
# Appending ARI score 0.4313682106933326 for period ending 2017-09-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-04 00:00:00 for 32793 orders.
# Appending ARI score 0.43053641880428106 for period ending 2017-10-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-11 00:00:00 for 34006 orders.
# Appending ARI score 0.43381033814853076 for period ending 2017-10-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-18 00:00:00 for 35358 orders.
# Appending ARI score 0.3319064418413116 for period ending 2017-10-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-25 00:00:00 for 36598 orders.
# Appending ARI score 0.42432644668583247 for period ending 2017-10-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-01 00:00:00 for 37724 orders.
# Appending ARI score 0.30754803358631727 for period ending 2017-11-01 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-08 00:00:00 for 38948 orders.
# Appending ARI score 0.4184942926798826 for period ending 2017-11-08 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-15 00:00:00 for 40440 orders.
# Appending ARI score 0.4274242646975141 for period ending 2017-11-15 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-22 00:00:00 for 42056 orders.
# Appending ARI score 0.3335277017125394 for period ending 2017-11-22 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-29 00:00:00 for 46242 orders.
# Appending ARI score 0.46265127791711147 for period ending 2017-11-29 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-06 00:00:00 for 48409 orders.
# Appending ARI score 0.5087660282780826 for period ending 2017-12-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-13 00:00:00 for 50187 orders.
# Appending ARI score 0.4564519354096651 for period ending 2017-12-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-20 00:00:00 for 51559 orders.
# Appending ARI score 0.44800830401752817 for period ending 2017-12-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-27 00:00:00 for 52495 orders.
# Appending ARI score 0.22765362827330235 for period ending 2017-12-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-03 00:00:00 for 53567 orders.
# Appending ARI score 0.20607994848835345 for period ending 2018-01-03 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-10 00:00:00 for 55521 orders.
# Appending ARI score 0.3972397328071225 for period ending 2018-01-10 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-17 00:00:00 for 57662 orders.
# Appending ARI score 0.4053598103434667 for period ending 2018-01-17 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-24 00:00:00 for 59574 orders.
# Appending ARI score 0.41021354090121315 for period ending 2018-01-24 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-31 00:00:00 for 61378 orders.
# Appending ARI score 0.4005604238231354 for period ending 2018-01-31 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-07 00:00:00 for 63287 orders.
# Appending ARI score 0.39668953630099574 for period ending 2018-02-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-14 00:00:00 for 65083 orders.
# Appending ARI score 0.38772470137974974 for period ending 2018-02-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-21 00:00:00 for 67054 orders.
# Appending ARI score 0.38603754628022047 for period ending 2018-02-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-28 00:00:00 for 69274 orders.
# Appending ARI score 0.38283555546554593 for period ending 2018-02-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-07 00:00:00 for 71333 orders.
# Appending ARI score 0.37714798140937356 for period ending 2018-03-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-14 00:00:00 for 73090 orders.
# Appending ARI score 0.37072868341201765 for period ending 2018-03-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-21 00:00:00 for 75246 orders.
# Appending ARI score 0.2907859117752412 for period ending 2018-03-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-28 00:00:00 for 77107 orders.
# Appending ARI score 0.28116837455084503 for period ending 2018-03-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-04 00:00:00 for 78889 orders.
# Appending ARI score 0.2694679752640438 for period ending 2018-04-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-11 00:00:00 for 80649 orders.
# Appending ARI score 0.27314269279797054 for period ending 2018-04-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-18 00:00:00 for 82623 orders.
# Appending ARI score 0.37705207732945767 for period ending 2018-04-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-25 00:00:00 for 84635 orders.
# Appending ARI score 0.37283266686541117 for period ending 2018-04-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-02 00:00:00 for 86579 orders.
# Appending ARI score 0.3730516324102009 for period ending 2018-05-02 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-09 00:00:00 for 88939 orders.
# Appending ARI score 0.31112964091159867 for period ending 2018-05-09 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-16 00:00:00 for 91370 orders.
# Appending ARI score 0.31608619274800515 for period ending 2018-05-16 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-23 00:00:00 for 92932 orders.
# Appending ARI score 0.2824945601308732 for period ending 2018-05-23 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-30 00:00:00 for 93946 orders.
# Appending ARI score 0.24978557966851164 for period ending 2018-05-30 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-06 00:00:00 for 95498 orders.
# Appending ARI score 0.24926132519206332 for period ending 2018-06-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-13 00:00:00 for 97418 orders.
# Appending ARI score 0.34666983048950123 for period ending 2018-06-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-20 00:00:00 for 99080 orders.
# Appending ARI score 0.3514855381012327 for period ending 2018-06-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-27 00:00:00 for 100836 orders.
# Appending ARI score 0.3487491955230007 for period ending 2018-06-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-04 00:00:00 for 102427 orders.
# Appending ARI score 0.34422229367530277 for period ending 2018-07-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-11 00:00:00 for 103500 orders.
# Appending ARI score 0.324117839659081 for period ending 2018-07-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-18 00:00:00 for 105064 orders.
# Appending ARI score 0.3265573331385213 for period ending 2018-07-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-25 00:00:00 for 107097 orders.
# Appending ARI score 0.33964026920517426 for period ending 2018-07-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-01 00:00:00 for 109144 orders.
# Appending ARI score 0.34023556114080955 for period ending 2018-08-01 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-08 00:00:00 for 111683 orders.
# Appending ARI score 0.34828227214660284 for period ending 2018-08-08 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-15 00:00:00 for 113750 orders.
# Appending ARI score 0.30258252656430085 for period ending 2018-08-15 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-22 00:00:00 for 115629 orders.
# Appending ARI score 0.28599964511769904 for period ending 2018-08-22 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-29 00:00:00 for 116210 orders.
# Appending ARI score 0.2948630393446616 for period ending 2018-08-29 00:00:00
# Current dataset is from 2017-01-05 00:00:00 to 2018-08-29 00:00:00
# /var/folders/4f/ml64c07d1zsg_jvvydhyltjr0000gn/T/ipykernel_11092/2858917906.py:77: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Functions

# %% [markdown]
# ## Aggregate

# %%
def aggregate_to_customer(
    df: pd.DataFrame,
    last: pd.Timestamp,
    start: pd.Timestamp,
    period: str,
    period_lapse: int,
) -> tuple:
    """ Build the customer dataframe according to periods

    Args:
        df (pd.DataFrame): the dataframe to aggregate (df_orders)
        last (pd.Timestamp): the date from which to calculate the recency
        start (pd.Timestamp): the date to start the aggregation
        period (str): the period to calculate the frequency ("week" or "month")
        period_laps (int): the number of weeks/months to calculate the frequency

    Returns:
        tuple: the customer dataframe, the one scaled with log and the last date of the dataset of the current dataset
    """
    df_copy = df.copy()
    # Change dates column to pd.datetime
    df_copy["order_purchase_date"] = pd.to_datetime(df_copy["order_purchase_date"])

    # Select the period in the dataframe
    if period == "week":
        mask = df_copy["order_purchase_date"] <= last + pd.DateOffset(weeks=period_lapse)
    elif period == "month":
        mask = df_copy["order_purchase_date"] <= last + pd.DateOffset(months=period_lapse)
    else:
        raise ValueError("The period should be either week or month")
    df_period = df_copy[(df_copy["order_purchase_date"] >= start) & mask]

    print(f"Working on orders from {start} to {df_period['order_purchase_date'].max()} for {df_period.shape[0]} orders.")

    last_date_of_orders = df_period["order_purchase_date"].max()

    # Update the customer aggregation
    df_sorted = df_period.sort_values(by=["customer_unique_id", "order_purchase_date"])
    df_grouped = df_sorted.groupby("customer_unique_id")

    df_customers = df_grouped.agg(
        first_order_date=("order_purchase_date", "min"),
        last_order_date=("order_purchase_date", "max"),
        total_orders=("order_id", "count"),
        total_expenses=("payment_value", "sum"),
        average_review_score=("review_score", "mean"),
        # usual_moment_of_order_str=("order_purchase_time_bin", lambda x: x.mode()[0]),
        # average_delivery_delays=("delivery_delay", "mean"),
        average_days_late=("days_late_count", "mean"),
        cancelled_orders=("canceled_orders", "sum"),
    )


    # Get the last date of the dataset
    last_date_of_orders = df_period["order_purchase_date"].max()

    df_customers = df_customers.reset_index()

    # Calculate the number of days since the last order
    df_customers["days_since_last_order"] = (last_date_of_orders - df_customers["last_order_date"]).dt.days
    # replace 0 days by 1 day to avoid having 0
    df_customers["days_since_last_order"] = df_customers["days_since_last_order"].apply(
        lambda x: 1 if x == 0 else x
    )
    # time_of_day_order = ["Night", "Morning", "Noon", "Afternoon", "Evening"]
    # df_customers["usual_moment_of_order_int"] = df_customers[
    #  "usual_moment_of_order_str"].apply(lambda x: time_of_day_order.index(x)).astype(int)

    # drop rows where total orders = total cancelled orders
    df_customers = df_customers[df_customers["total_orders"] != df_customers["cancelled_orders"]]

    # columns to drop to get back to our final cluster dataframe
    columns_to_drop = [
        "customer_unique_id",
        "first_order_date",
        "last_order_date",
        # "usual_moment_of_order_str",
        "cancelled_orders",
    ]

    df_customers = df_customers.drop(columns=columns_to_drop)

    df_customers_log = df_customers.copy()
    df_customers_log = np.log1p(df_customers)


    return df_customers, df_customers_log, last_date_of_orders

# %% [markdown]
# ## Visualize

# %%
def plot_two_dim_clusters(df: pd.DataFrame, scaled_df: pd.DataFrame, k: int):
    """Plots clusters after reducing the data to 2 dimensions using PCA

    Args:
        df (pd.DataFrame): original dataframe
        scaled_df (pd.DataFrame): dataframe with scaled features used for clustering
        k (int): number of clusters to try
    """
    pca = PCA(n_components=2)
    reduced_df = pca.fit_transform(scaled_df)
    features_names = df.columns.tolist()

    model = KMeans(k, random_state=42, max_iter=300)
    labels = model.fit_predict(reduced_df)

    # Add cluster to the original dataframe
    df["cluster"] = labels

    # Plot clusters
    u_labels = np.unique(labels)
    plt.figure(figsize=(10, 10))
    for i in u_labels:
        plt.scatter(
            reduced_df[labels == i, 0],
            reduced_df[labels == i, 1],
            label=f"Cluster {i}",
        )
    # take cluster out of the features list
    plt.legend()
    plt.title(f"Clusters with k={k} for {features_names}")
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.show()

# %% [markdown]
# ## Evaluation

# %%
def plot_ari_evolution(first_order_date: pd.Timestamp, f: list[int], k: int, period : list[str], df_base: pd.DataFrame = df_orders):
    """Plot the ARI score evolution over time

    Args:
        first_order_date (pd.Timestamp): starting date of the dataset
        f (list[int]): frequency of the data aggregation. First element is the number of weeks or months for the base dataset, second element is the number of weeks or months for the current dataset, then for the interval to calculate the ARI score
        k (int): Number of clusters to try
        period (list[str]): "week" or "month". First element is the period for the base dataset, second element is the period for the current dataset
        df_base (pd.DataFrame, optional): DataFrame to use for aggregation. Defaults to df_orders.
    """

    i = 0 # iteration
    # Get first data
    original_customers, customers_reference_log, last_date_of_orders = aggregate_to_customer(
        df_base, first_order_date, first_order_date, period[0], f[0]
    )

    print(original_customers.info())
    # Store ARI score in a list
    ari_scores = []

    # Fit the KMeans model on the first week of data
    kmeans_ref = KMeans(n_clusters=k, random_state=42, max_iter=300)
    kmeans_ref.fit(customers_reference_log)

    while last_date_of_orders < pd.to_datetime("2018-08-29"):
        if i == 0:
            current_customers, customers_current_log, last_date_of_orders = (
                aggregate_to_customer(
                    df_base, first_order_date, first_order_date, period[0], f[0]
                )
            )
            # Plot the first week of data
            plot_two_dim_clusters(
                current_customers,
                customers_current_log,
                k,
            )
        else:
            # Update data with current period
            current_customers, customers_current_log, last_date_of_orders = (
                aggregate_to_customer(
                    df_base, last_date_of_orders, first_order_date, period[1], f[1]
                )
            )

        i += 1
        # predict initial model
        reference_labels = kmeans_ref.predict(customers_current_log)

        # refit the model
        kmeans_current = KMeans(n_clusters=k, random_state=42, max_iter=300)
        current_labels = kmeans_current.fit_predict(customers_current_log)


        # Calculate ARI score between current and previous period
        ari = adjusted_rand_score(reference_labels, current_labels)

        print(f"Appending ARI score {ari} for period ending {last_date_of_orders}")
        ari_scores.append((last_date_of_orders, ari))


    print(f"Current dataset is from {first_order_date} to {last_date_of_orders}")
    plot_two_dim_clusters(
        current_customers,
        customers_current_log,
        k,
    )


    # Plot the ARI score evolution
    periods = [period_end for period_end, _ in ari_scores]
    ari_values = [ari for _, ari in ari_scores]

    plt.figure(figsize=(10, 6))
    plt.plot(periods, ari_values, marker="o", linestyle="-", color="b")
    plt.legend()
    plt.axhline(y=0.8, color="r", linestyle="--")
    plt.xlabel("Period End Date")
    plt.ylabel("ARI Score")
    plt.title(f"ARI Score Evolution Over Time from {first_order_date.date()} with interval of {f[1]} {period[1]}(s)")
    plt.xticks(periods, rotation=90)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def compare(first_order_date: pd.Timestamp, f: list[int], k: int, period: list[str]):
    """Compare the ARI score evolution between two models

    """
    i=0
    ari_scores = []
    # First model is 3 months of data
    original_customers, customers_reference_log, last_date_of_orders = aggregate_to_customer(
        df_orders, first_order_date, first_order_date, period[0], f[0]
    )
    # fit reference model
    kmeans_ref = KMeans(n_clusters=k, random_state=42, max_iter=300)
    kmeans_ref.fit(customers_reference_log)

    while last_date_of_orders < pd.to_datetime("2018-08-29"):
        # If i is a multiple of 4
        if i % 4 == 0 and i != 0:
            original_customers, customers_reference_log, last_date_of_orders = (
                aggregate_to_customer(
                    df_orders, last_date_of_orders, first_order_date, period[1], f[1]
                )
            )
            # fit the model
            kmeans_ref = KMeans(n_clusters=k, random_state=42, max_iter=300)
            kmeans_ref.fit(customers_reference_log)

        if i == 0:
            current_customers, customers_current_log, last_date_of_orders = aggregate_to_customer(
                df_orders, last_date_of_orders, first_order_date, period[1], f[1]
            )
        else:
            # current period
            current_customers, customers_current_log, last_date_of_orders = aggregate_to_customer(
                df_orders, last_date_of_orders, first_order_date, period[1], f[1]
            )
        i += 1
        # predict initial model
        reference_labels = kmeans_ref.predict(customers_current_log)

        # refit the model
        kmeans_current = KMeans(n_clusters=k, random_state=42, max_iter=300)
        current_labels = kmeans_current.fit_predict(customers_current_log)

        # Calculate ARI score between current and previous period
        ari = adjusted_rand_score(reference_labels, current_labels)

        print(f"Appending ARI score {ari} for period ending {last_date_of_orders}")
        ari_scores.append((last_date_of_orders, ari))

    print(f"Current dataset is from {first_order_date} to {last_date_of_orders}")
    plot_two_dim_clusters(
        current_customers,
        customers_current_log,
        k,
    )

    # Plot the ARI score evolution
    periods = [period_end for period_end, _ in ari_scores]
    ari_values = [ari for _, ari in ari_scores]

    plt.figure(figsize=(10, 6))
    plt.plot(periods, ari_values, marker="o", linestyle="-", color="b")
    plt.legend()
    plt.axhline(y=0.8, color="r", linestyle="--")
    plt.xlabel("Period End Date")
    plt.ylabel("ARI Score")
    plt.title(
        f"ARI Score Evolution Over Time from {first_order_date.date()} with interval of {f[1]} {period[1]}(s)"
    )
    plt.xticks(periods, rotation=90)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # ARI scores

# %%
first_order_date = pd.to_datetime(df_orders["order_purchase_date"].min())
period = ["month", "week"]
f = [3, 1]
plot_ari_evolution(first_order_date, f, k, period)
# Out:
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# <class 'pandas.core.frame.DataFrame'>
# Index: 5273 entries, 0 to 5312
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_orders           5273 non-null   int64
#  1   total_expenses         5273 non-null   float64
#  2   average_review_score   5273 non-null   float64
#  3   average_days_late      5273 non-null   float64
#  4   days_since_last_order  5273 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 247.2 KB
# None
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# Appending ARI score 1.0 for period ending 2017-04-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-12 00:00:00 for 7229 orders.
# Appending ARI score 0.41174163113016365 for period ending 2017-04-12 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-19 00:00:00 for 7742 orders.
# Appending ARI score 0.2702981000502518 for period ending 2017-04-19 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-26 00:00:00 for 8576 orders.
# Appending ARI score 0.8917342636732125 for period ending 2017-04-26 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-03 00:00:00 for 9339 orders.
# Appending ARI score 0.3955698789588096 for period ending 2017-05-03 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-10 00:00:00 for 10286 orders.
# Appending ARI score 0.3721801787054556 for period ending 2017-05-10 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-17 00:00:00 for 11337 orders.
# Appending ARI score 0.36872030841210274 for period ending 2017-05-17 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-24 00:00:00 for 12393 orders.
# Appending ARI score 0.7719886462239488 for period ending 2017-05-24 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-31 00:00:00 for 13286 orders.
# Appending ARI score 0.2530116563897519 for period ending 2017-05-31 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-07 00:00:00 for 14279 orders.
# Appending ARI score 0.28806096334303727 for period ending 2017-06-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-14 00:00:00 for 15252 orders.
# Appending ARI score 0.25384532821166544 for period ending 2017-06-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-21 00:00:00 for 16028 orders.
# Appending ARI score 0.23731394114101273 for period ending 2017-06-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-28 00:00:00 for 16814 orders.
# Appending ARI score 0.7189355293492931 for period ending 2017-06-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-05 00:00:00 for 17724 orders.
# Appending ARI score 0.23611187093087446 for period ending 2017-07-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-12 00:00:00 for 18778 orders.
# Appending ARI score 0.7657116303650656 for period ending 2017-07-12 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-19 00:00:00 for 20004 orders.
# Appending ARI score 0.24813806192077945 for period ending 2017-07-19 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-26 00:00:00 for 21080 orders.
# Appending ARI score 0.2650846141684522 for period ending 2017-07-26 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-02 00:00:00 for 22222 orders.
# Appending ARI score 0.25527327245195297 for period ending 2017-08-02 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-09 00:00:00 for 23396 orders.
# Appending ARI score 0.23365434388669223 for period ending 2017-08-09 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-16 00:00:00 for 24600 orders.
# Appending ARI score 0.656792376944468 for period ending 2017-08-16 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-23 00:00:00 for 25735 orders.
# Appending ARI score 0.2226186611063687 for period ending 2017-08-23 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-30 00:00:00 for 26822 orders.
# Appending ARI score 0.21366841529255867 for period ending 2017-08-30 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-06 00:00:00 for 27995 orders.
# Appending ARI score 0.20997164440086402 for period ending 2017-09-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-13 00:00:00 for 29210 orders.
# Appending ARI score 0.6598976913221751 for period ending 2017-09-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-20 00:00:00 for 30467 orders.
# Appending ARI score 0.6601286089321071 for period ending 2017-09-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-27 00:00:00 for 31618 orders.
# Appending ARI score 0.1962712059824048 for period ending 2017-09-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-04 00:00:00 for 32793 orders.
# Appending ARI score 0.19440650843039906 for period ending 2017-10-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-11 00:00:00 for 34006 orders.
# Appending ARI score 0.19468446174986576 for period ending 2017-10-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-18 00:00:00 for 35358 orders.
# Appending ARI score 0.20247177877231345 for period ending 2017-10-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-25 00:00:00 for 36598 orders.
# Appending ARI score 0.22164675952711624 for period ending 2017-10-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-01 00:00:00 for 37724 orders.
# Appending ARI score 0.17940961470831193 for period ending 2017-11-01 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-08 00:00:00 for 38948 orders.
# Appending ARI score 0.5942532613525018 for period ending 2017-11-08 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-15 00:00:00 for 40440 orders.
# Appending ARI score 0.6126150899584005 for period ending 2017-11-15 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-22 00:00:00 for 42056 orders.
# Appending ARI score 0.1969666001029411 for period ending 2017-11-22 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-29 00:00:00 for 46242 orders.
# Appending ARI score 0.6733885759833704 for period ending 2017-11-29 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-06 00:00:00 for 48409 orders.
# Appending ARI score 0.23020354828599032 for period ending 2017-12-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-13 00:00:00 for 50187 orders.
# Appending ARI score 0.2478623964323162 for period ending 2017-12-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-20 00:00:00 for 51559 orders.
# Appending ARI score 0.4758253617000616 for period ending 2017-12-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-27 00:00:00 for 52495 orders.
# Appending ARI score 0.14363386364620853 for period ending 2017-12-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-03 00:00:00 for 53567 orders.
# Appending ARI score 0.43471984262165136 for period ending 2018-01-03 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-10 00:00:00 for 55521 orders.
# Appending ARI score 0.18044351637447847 for period ending 2018-01-10 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-17 00:00:00 for 57662 orders.
# Appending ARI score 0.18922038583829473 for period ending 2018-01-17 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-24 00:00:00 for 59574 orders.
# Appending ARI score 0.17232388159974302 for period ending 2018-01-24 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-31 00:00:00 for 61378 orders.
# Appending ARI score 0.2086958217772644 for period ending 2018-01-31 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-07 00:00:00 for 63287 orders.
# Appending ARI score 0.15683281159723292 for period ending 2018-02-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-14 00:00:00 for 65083 orders.
# Appending ARI score 0.15815980267466745 for period ending 2018-02-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-21 00:00:00 for 67054 orders.
# Appending ARI score 0.158919234249063 for period ending 2018-02-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-28 00:00:00 for 69274 orders.
# Appending ARI score 0.1767745225790726 for period ending 2018-02-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-07 00:00:00 for 71333 orders.
# Appending ARI score 0.17522761784713414 for period ending 2018-03-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-14 00:00:00 for 73090 orders.
# Appending ARI score 0.15200608771165625 for period ending 2018-03-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-21 00:00:00 for 75246 orders.
# Appending ARI score 0.18568359554390385 for period ending 2018-03-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-28 00:00:00 for 77107 orders.
# Appending ARI score 0.18787887668695205 for period ending 2018-03-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-04 00:00:00 for 78889 orders.
# Appending ARI score 0.1797070300749263 for period ending 2018-04-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-11 00:00:00 for 80649 orders.
# Appending ARI score 0.1530368723143875 for period ending 2018-04-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-18 00:00:00 for 82623 orders.
# Appending ARI score 0.1548584825363413 for period ending 2018-04-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-25 00:00:00 for 84635 orders.
# Appending ARI score 0.19049063051001144 for period ending 2018-04-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-02 00:00:00 for 86579 orders.
# Appending ARI score 0.18227075263644985 for period ending 2018-05-02 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-09 00:00:00 for 88939 orders.
# Appending ARI score 0.19080746396086815 for period ending 2018-05-09 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-16 00:00:00 for 91370 orders.
# Appending ARI score 0.5209240306642198 for period ending 2018-05-16 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-23 00:00:00 for 92932 orders.
# Appending ARI score 0.17160719663932172 for period ending 2018-05-23 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-30 00:00:00 for 93946 orders.
# Appending ARI score 0.149991267036256 for period ending 2018-05-30 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-06 00:00:00 for 95498 orders.
# Appending ARI score 0.14923124182599204 for period ending 2018-06-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-13 00:00:00 for 97418 orders.
# Appending ARI score 0.5128702194980101 for period ending 2018-06-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-20 00:00:00 for 99080 orders.
# Appending ARI score 0.14723548987279972 for period ending 2018-06-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-27 00:00:00 for 100836 orders.
# Appending ARI score 0.15584273300249094 for period ending 2018-06-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-04 00:00:00 for 102427 orders.
# Appending ARI score 0.15538987855766775 for period ending 2018-07-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-11 00:00:00 for 103500 orders.
# Appending ARI score 0.14744007891116154 for period ending 2018-07-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-18 00:00:00 for 105064 orders.
# Appending ARI score 0.14921216155316852 for period ending 2018-07-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-25 00:00:00 for 107097 orders.
# Appending ARI score 0.1761732060583059 for period ending 2018-07-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-01 00:00:00 for 109144 orders.
# Appending ARI score 0.18253863671468132 for period ending 2018-08-01 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-08 00:00:00 for 111683 orders.
# Appending ARI score 0.18882239188039104 for period ending 2018-08-08 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-15 00:00:00 for 113750 orders.
# Appending ARI score 0.18605835073041554 for period ending 2018-08-15 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-22 00:00:00 for 115629 orders.
# Appending ARI score 0.5477461692574448 for period ending 2018-08-22 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-29 00:00:00 for 116210 orders.
# Appending ARI score 0.14407986450725105 for period ending 2018-08-29 00:00:00
# Current dataset is from 2017-01-05 00:00:00 to 2018-08-29 00:00:00
# /var/folders/4f/ml64c07d1zsg_jvvydhyltjr0000gn/T/ipykernel_11092/2858917906.py:77: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
period = ["month", "month"]
f = [3, 1]
plot_ari_evolution(first_order_date, f, k, period)
# Out:
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# <class 'pandas.core.frame.DataFrame'>
# Index: 5273 entries, 0 to 5312
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_orders           5273 non-null   int64
#  1   total_expenses         5273 non-null   float64
#  2   average_review_score   5273 non-null   float64
#  3   average_days_late      5273 non-null   float64
#  4   days_since_last_order  5273 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 247.2 KB
# None
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# Appending ARI score 1.0 for period ending 2017-04-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-05 00:00:00 for 9590 orders.
# Appending ARI score 0.390219597503406 for period ending 2017-05-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-05 00:00:00 for 13961 orders.
# Appending ARI score 0.28764192061995547 for period ending 2017-06-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-05 00:00:00 for 17724 orders.
# Appending ARI score 0.23611187093087446 for period ending 2017-07-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-05 00:00:00 for 22687 orders.
# Appending ARI score 0.2462660890887582 for period ending 2017-08-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-05 00:00:00 for 27827 orders.
# Appending ARI score 0.6436042863454124 for period ending 2017-09-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-05 00:00:00 for 32962 orders.
# Appending ARI score 0.22708247075816915 for period ending 2017-10-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-05 00:00:00 for 38356 orders.
# Appending ARI score 0.17906396713709066 for period ending 2017-11-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-05 00:00:00 for 48084 orders.
# Appending ARI score 0.23617944589937484 for period ending 2017-12-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-05 00:00:00 for 54104 orders.
# Appending ARI score 0.1413272010758477 for period ending 2018-01-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-05 00:00:00 for 62686 orders.
# Appending ARI score 0.15397484293793373 for period ending 2018-02-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-05 00:00:00 for 70731 orders.
# Appending ARI score 0.5490027446926431 for period ending 2018-03-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-05 00:00:00 for 79200 orders.
# Appending ARI score 0.15926648491392245 for period ending 2018-04-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-05 00:00:00 for 87480 orders.
# Appending ARI score 0.18498000399675202 for period ending 2018-05-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-05 00:00:00 for 95216 orders.
# Appending ARI score 0.14798345498864107 for period ending 2018-06-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-05 00:00:00 for 102650 orders.
# Appending ARI score 0.1558426384887416 for period ending 2018-07-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-05 00:00:00 for 110439 orders.
# Appending ARI score 0.14559068244384815 for period ending 2018-08-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-09-03 00:00:00 for 116211 orders.
# Appending ARI score 0.12734253534653872 for period ending 2018-09-03 00:00:00
# Current dataset is from 2017-01-05 00:00:00 to 2018-09-03 00:00:00
# /var/folders/4f/ml64c07d1zsg_jvvydhyltjr0000gn/T/ipykernel_11092/2858917906.py:77: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
period = ["month", "week"]
f = [3, 1]
compare(first_order_date, f, k, period)
# Out:
# Working on orders from 2017-01-05 00:00:00 to 2017-04-05 00:00:00 for 6612 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-04-12 00:00:00 for 7229 orders.
# Appending ARI score 0.41174163113016365 for period ending 2017-04-12 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-19 00:00:00 for 7742 orders.
# Appending ARI score 0.2702981000502518 for period ending 2017-04-19 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-04-26 00:00:00 for 8576 orders.
# Appending ARI score 0.8917342636732125 for period ending 2017-04-26 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-03 00:00:00 for 9339 orders.
# Appending ARI score 0.3955698789588096 for period ending 2017-05-03 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-10 00:00:00 for 10286 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-05-17 00:00:00 for 11337 orders.
# Appending ARI score 0.958464538995128 for period ending 2017-05-17 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-24 00:00:00 for 12393 orders.
# Appending ARI score 0.4761825995085136 for period ending 2017-05-24 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-05-31 00:00:00 for 13286 orders.
# Appending ARI score 0.5380536552042671 for period ending 2017-05-31 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-07 00:00:00 for 14279 orders.
# Appending ARI score 0.8362654336733683 for period ending 2017-06-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-14 00:00:00 for 15252 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-06-21 00:00:00 for 16028 orders.
# Appending ARI score 0.9067585369384967 for period ending 2017-06-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-06-28 00:00:00 for 16814 orders.
# Appending ARI score 0.2963255343975629 for period ending 2017-06-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-05 00:00:00 for 17724 orders.
# Appending ARI score 0.8087332106315274 for period ending 2017-07-05 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-12 00:00:00 for 18778 orders.
# Appending ARI score 0.3073035800743898 for period ending 2017-07-12 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-07-19 00:00:00 for 20004 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-07-26 00:00:00 for 21080 orders.
# Appending ARI score 0.5813551565611751 for period ending 2017-07-26 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-02 00:00:00 for 22222 orders.
# Appending ARI score 0.5862502545981945 for period ending 2017-08-02 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-09 00:00:00 for 23396 orders.
# Appending ARI score 0.94450195563181 for period ending 2017-08-09 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-16 00:00:00 for 24600 orders.
# Appending ARI score 0.32317070493829725 for period ending 2017-08-16 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-08-23 00:00:00 for 25735 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-08-30 00:00:00 for 26822 orders.
# Appending ARI score 0.9662167944099294 for period ending 2017-08-30 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-06 00:00:00 for 27995 orders.
# Appending ARI score 0.943313900442827 for period ending 2017-09-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-13 00:00:00 for 29210 orders.
# Appending ARI score 0.3074666143545279 for period ending 2017-09-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-20 00:00:00 for 30467 orders.
# Appending ARI score 0.3134632614669096 for period ending 2017-09-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-09-27 00:00:00 for 31618 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-10-04 00:00:00 for 32793 orders.
# Appending ARI score 0.972773547400785 for period ending 2017-10-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-11 00:00:00 for 34006 orders.
# Appending ARI score 0.9566993723577206 for period ending 2017-10-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-18 00:00:00 for 35358 orders.
# Appending ARI score 0.9161112180902489 for period ending 2017-10-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-10-25 00:00:00 for 36598 orders.
# Appending ARI score 0.5705278610046275 for period ending 2017-10-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-01 00:00:00 for 37724 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-11-08 00:00:00 for 38948 orders.
# Appending ARI score 0.2976689044139377 for period ending 2017-11-08 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-15 00:00:00 for 40440 orders.
# Appending ARI score 0.29875079231336016 for period ending 2017-11-15 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-22 00:00:00 for 42056 orders.
# Appending ARI score 0.950137283569623 for period ending 2017-11-22 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-11-29 00:00:00 for 46242 orders.
# Appending ARI score 0.3375148517033924 for period ending 2017-11-29 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-06 00:00:00 for 48409 orders.
# Working on orders from 2017-01-05 00:00:00 to 2017-12-13 00:00:00 for 50187 orders.
# Appending ARI score 0.46769312084694653 for period ending 2017-12-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-20 00:00:00 for 51559 orders.
# Appending ARI score 0.33853757894950204 for period ending 2017-12-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2017-12-27 00:00:00 for 52495 orders.
# Appending ARI score 0.6615940074985404 for period ending 2017-12-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-03 00:00:00 for 53567 orders.
# Appending ARI score 0.39002435631722515 for period ending 2018-01-03 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-10 00:00:00 for 55521 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-01-17 00:00:00 for 57662 orders.
# Appending ARI score 0.9087667653290771 for period ending 2018-01-17 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-24 00:00:00 for 59574 orders.
# Appending ARI score 0.8355542827047041 for period ending 2018-01-24 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-01-31 00:00:00 for 61378 orders.
# Appending ARI score 0.5124004980054434 for period ending 2018-01-31 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-07 00:00:00 for 63287 orders.
# Appending ARI score 0.7981110956427071 for period ending 2018-02-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-14 00:00:00 for 65083 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-02-21 00:00:00 for 67054 orders.
# Appending ARI score 0.9771069845476988 for period ending 2018-02-21 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-02-28 00:00:00 for 69274 orders.
# Appending ARI score 0.522121126516397 for period ending 2018-02-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-07 00:00:00 for 71333 orders.
# Appending ARI score 0.524037041793728 for period ending 2018-03-07 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-14 00:00:00 for 73090 orders.
# Appending ARI score 0.882350566681085 for period ending 2018-03-14 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-03-21 00:00:00 for 75246 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-03-28 00:00:00 for 77107 orders.
# Appending ARI score 0.9747610198530583 for period ending 2018-03-28 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-04 00:00:00 for 78889 orders.
# Appending ARI score 0.9766747289988392 for period ending 2018-04-04 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-11 00:00:00 for 80649 orders.
# Appending ARI score 0.6010823232405164 for period ending 2018-04-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-18 00:00:00 for 82623 orders.
# Appending ARI score 0.5849848947634704 for period ending 2018-04-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-04-25 00:00:00 for 84635 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-05-02 00:00:00 for 86579 orders.
# Appending ARI score 0.9668472348290889 for period ending 2018-05-02 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-09 00:00:00 for 88939 orders.
# Appending ARI score 0.9945487055120946 for period ending 2018-05-09 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-16 00:00:00 for 91370 orders.
# Appending ARI score 0.4324832689870845 for period ending 2018-05-16 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-23 00:00:00 for 92932 orders.
# Appending ARI score 0.9384920481612606 for period ending 2018-05-23 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-05-30 00:00:00 for 93946 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-06-06 00:00:00 for 95498 orders.
# Appending ARI score 0.9895620129382133 for period ending 2018-06-06 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-13 00:00:00 for 97418 orders.
# Appending ARI score 0.449038196409249 for period ending 2018-06-13 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-20 00:00:00 for 99080 orders.
# Appending ARI score 0.589973208766045 for period ending 2018-06-20 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-06-27 00:00:00 for 100836 orders.
# Appending ARI score 0.973311110597386 for period ending 2018-06-27 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-04 00:00:00 for 102427 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-07-11 00:00:00 for 103500 orders.
# Appending ARI score 0.9469952937717767 for period ending 2018-07-11 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-18 00:00:00 for 105064 orders.
# Appending ARI score 0.9629347690325716 for period ending 2018-07-18 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-07-25 00:00:00 for 107097 orders.
# Appending ARI score 0.9298473295205867 for period ending 2018-07-25 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-01 00:00:00 for 109144 orders.
# Appending ARI score 0.914002442964086 for period ending 2018-08-01 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-08 00:00:00 for 111683 orders.
# Working on orders from 2017-01-05 00:00:00 to 2018-08-15 00:00:00 for 113750 orders.
# Appending ARI score 0.9816079468872406 for period ending 2018-08-15 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-22 00:00:00 for 115629 orders.
# Appending ARI score 0.4156018928319535 for period ending 2018-08-22 00:00:00
# Working on orders from 2017-01-05 00:00:00 to 2018-08-29 00:00:00 for 116210 orders.
# Appending ARI score 0.8619491242873258 for period ending 2018-08-29 00:00:00
# Current dataset is from 2017-01-05 00:00:00 to 2018-08-29 00:00:00
# /var/folders/4f/ml64c07d1zsg_jvvydhyltjr0000gn/T/ipykernel_11092/3726858343.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
